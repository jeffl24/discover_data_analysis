# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option("display.max_columns", 100)

# Import Shopify sales_data (dated 2018-02-07) and perform basic formatting 
sales_data = pd.read_csv("C:\\Users\limzi\OneDrive\Forecasting & Reporting\Jeff Files\PowerBi Files\pcsg_shopify_debundled\pcsg_shopify_orders_debundled.csv", 
                         low_memory=False, 
                         parse_dates=['Paid at', 'Created at'])

sales_data_clean = sales_data.drop(sales_data.columns.to_series()[-11:-1], axis=1)
sales_data_clean.dropna(subset=['Email'], axis=0, inplace=True)

# %%
pre_free_ship_sales = sales_data_clean[sales_data_clean['Created at']< "2018-06-01"]
post_free_ship_sales = sales_data_clean[sales_data_clean['Created at']>= "2018-06-01"]

# %%
sales_data_clean.head()
# Out:
#    Unnamed: 0          Name                         Email             Paid at  \
# 0           0         test3              wytanj@gmail.com 2016-10-12 18:36:52
# 1           1  191569923861  nalinimoorthi_19@hotmail.com 2018-10-16 10:54:57
# 2           2  191569923861  nalinimoorthi_19@hotmail.com                 NaT
# 3           3  191569923860            pf.chong@gmail.com 2018-10-16 09:08:19
# 4           4  191569923860            pf.chong@gmail.com                 NaT
#
#    Subtotal  Shipping  Taxes  Total      Discount Code  Discount Amount  \
# 0       3.0       8.0    0.0   11.0                NaN              0.0
# 1      57.0       0.0    0.0   57.0  25OFFdc01270b73cb             25.0
# 2       NaN       NaN    NaN    NaN                NaN              NaN
# 3     113.0       0.0    0.0  113.0                NaN              0.0
# 4       NaN       NaN    NaN    NaN                NaN              NaN
#
#            Created at  Lineitem quantity  \
# ...

# %%
pre_free_ship_sales[pre_free_ship_sales['Email'] == "tse.germaine@gmail.com"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Email, Paid at, Subtotal, Shipping, Taxes, Total, Discount Code, Discount Amount, Created at, Lineitem quantity, Lineitem name, Lineitem price, Lineitem compare at price, Lineitem sku, Lineitem discount, parent_sku, parent_name, bundle_status]
# Index: []

# %%
new_users_from_post_freeship_sales = post_free_ship_sales[~post_free_ship_sales['Email'].isin(pre_free_ship_sales['Email'].unique())]

# %%
new_users_from_post_freeship_sales.groupby(['Email']).first().reset_index()['Subtotal'].describe()
# Out:
# count    1380.000000
# mean       66.576775
# std        59.911882
# min         0.000000
# 25%        34.000000
# 50%        45.000000
# 75%        86.000000
# max       541.500000
# Name: Subtotal, dtype: float64

# %%
new_users_from_post_freeship_sales.groupby(['Email']).first().reset_index()['Email'].value_counts()
# Out:
# tse.germaine@gmail.com                1
# clanne30011@gmail.com                 1
# iamyerdua@gmail.com                   1
# bulbasarous@gmail.com                 1
# YUXUAN37@HOTMAIL.COM                  1
# hgbunnys@hotmail.com                  1
# dannypaula0005@gmail.com              1
# jenniferchan@mediacorp.com.sg         1
# andreosity@yahoo.com.sg               1
# ongblu@hotmail.com                    1
# louise_zy@hotmail.com                 1
# felicia.jiamin@hotmail.com            1
# jerenekwy@hotmail.com                 1
# joncsy@gmail.com                      1
# hammypiee@gmail.com                   1
# bryanlu20@gmail.com                   1
# tan.amelia@gmail.com                  1
# mit8985@yahoo.com                     1
# ch.michelle.chia@gmail.com            1
# bubbles_footprints@yahoo.com.sg       1
# ggglitter+paulaschoicesg@gmail.com    1
# joanneliujingjing@gmail.com           1
# nurinadilashahrin@gmail.com           1
# ...
