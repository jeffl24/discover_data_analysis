# %% [markdown]
# # Part 1 - Obtaining and formatting Discover Data

# %%
import numpy as np
import pandas as pd
import ast
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option("display.max_columns", 100)

# %%
# import discover data, and filter for list of emails according to their earliest use of discover
discover_data = pd.read_csv("discover_print_to_csv.csv")
discover_data['timestamp'] = discover_data['timestamp'].map(pd.to_datetime)

# In request.concerns column, both sensitive skin status and skin types are appended together with user's concerns.
# Need to use pandas apply to remove those entries

# However, we need to first convert each element in the request.concerns from "strings (of list)" to "list" type 

# In order to do that, we need to fill blank entries with an empty list in order for the function ast.literal_eval() 
# to be passed through successfully

columns_to_convert_list = ['concerns_addressed','match','request.concerns','reviews']

for column in columns_to_convert_list:
    
    discover_data[column] = discover_data[column].fillna("[]").map(lambda x: ast.literal_eval(x))

def remove_skin_types(x):
    terms_to_delete = ['Sensitivity', 'Combination','Dry to Very Dry', 'Normal', 'Oily']
    replacement_list = []
    for entry in x:
        if entry in terms_to_delete:
            del entry
        else:
            replacement_list.append(entry)
    return replacement_list
discover_data['request.concerns'] = discover_data['request.concerns'].map(remove_skin_types)

# Remove entries without gender indicated
discover_data = discover_data[~(discover_data['request.gender'] == 0) & (discover_data['Serial'] <9)]

# discover_data.to_csv('firebase_discover_formatted.csv')
# print(type(discover_data['timestamp'][0]))

# %%
single_row_recommendations = pd.DataFrame(discover_data.groupby(by = ['email', 
                                                    'timestamp',
                                                     'request.ageRange',
                                                      'request.gender',
                                                         'request.name',
                                                    'request.skinType'])['SKU'].apply(list)).reset_index()
single_row_recommendations = single_row_recommendations.drop_duplicates('email', keep='last')
single_row_recommendations.sort_values('timestamp')
# Out:
#                                email           timestamp  request.ageRange  \
# 2707             yaminnphyu@mail.com 2017-09-10 03:29:06              30.0
# 1863       littlelucky2000@gmail.com 2017-09-10 03:54:12              40.0
# 437               Mukhacho@gmail.com 2017-09-10 04:01:06              30.0
# 2109             nyc920319@gmail.com 2017-09-10 04:02:22              30.0
# 2687         wps-service@hotmail.com 2017-09-10 04:04:44              30.0
# 604           Stacygan1010@gmail.com 2017-09-10 04:06:05              40.0
# 379         Lemondropz_3@hotmail.com 2017-09-10 04:06:07              20.0
# 596             Soh_nee@yahoo.com.sg 2017-09-10 04:06:10              40.0
# 1034       charmaine_287@hotmail.com 2017-09-10 04:08:00              30.0
# 284   Jacquelyncheongemail@gmail.com 2017-09-10 04:09:14              30.0
# 172              Diontoh@hotmail.com 2017-09-10 04:11:11              30.0
# 551        Rusdi_budiman@hotmail.com 2017-09-10 04:11:17              30.0
# 2726          yeo_siow_wei@yahoo.com 2017-09-10 04:16:19              40.0
# 115            Cheeyanjing@gmail.com 2017-09-10 04:17:43              30.0
# 2538       teo.lorraine@yahoo.com.sg 2017-09-10 04:18:10              30.0
# 1850      lineatte.jz.tan@sg.pwc.com 2017-09-10 04:19:14              30.0
# 2602       tumpangtindih@hotmail.com 2017-09-10 04:19:25              30.0
# 525        Qingyiwillems@hotmail.com 2017-09-10 04:19:58              40.0
# 43              Amytan87@hotmail.com 2017-09-10 04:20:12              40.0
# 2388          shihyilim@yahoo.com.sg 2017-09-10 04:21:24              30.0
# 1796            laipeiwong@gmail.com 2017-09-10 04:23:57              40.0
# 284                2                  Jacquelyn      Combination
# 172                1                       Dion           Normal
# 551                1                      Rusdi      Combination
# 2726               2                        yeo      Combination
# 115                2                    Yanjing           Normal
# 2538               2                   Lorraine      Combination
# 1850               2                   Lineatte      Combination
# 2602               1  tumpangtindih@hotmail.com             Oily
# 525                2             Qingyi Willems             Oily
# 43                 2                        Amy             Oily
# 2388               1                      James           Normal
# 1796               2                    Lai Pei      Combination
# 801                2      ally_zi86@hotmail.com      Combination
# 566                1               Hong xiuxian      Combination
# 471                2                 Nurshazana           Normal
# 2695               2                    Xiaoqin      Combination
# 2794               1                      Zaron             Oily
# 455                2                    Natalie      Combination
# 1179               2                     Debbie      Combination
# 307                1                      Jaron             Oily
# 447                1                   Tyrhung              Oily
# ...              ...                        ...              ...
# 2756               2                    Natasha      Combination
# 250                2                       Hang      Combination
# 2065               2                      Arnie      Combination
# 2443               2                 Nurlutfiah      Combination
# 424                2               Michelle Yeo      Combination
# 2313               2                    sabrina             Oily
# 1254               2              Elfrida Rossi      Combination
# 2553               2                     Sandie           Normal
# 2062               2                     nicole      Combination
# 1787               2                    Kyanite      Combination
# 841                2                      Yilin           Normal
# 1718               2                       june      Combination
# 327                2                    Jocelyn           Normal
# 755                2                     diyana  Dry to Very Dry
# 2100               2             Liyaana Latiff      Combination
# 2237               2                        raz      Combination
# 225                2             FRANCESCA LEOW      Combination
# 1361               2                      Brina      Combination
# 1770               2                     Alyssa      Combination
# 2083               2                    noraini  Dry to Very Dry
# 1836               2                    Bernice             Oily
# 610                2           Michele Chambers           Normal
# 2026               2                    natalia      Combination
# 1789               2                      ginie             Oily
# 1287               2                Tammy Olson  Dry to Very Dry
# 519                2              Patsy roberts  Dry to Very Dry
# 1213               2                     dorcas      Combination
# 857                2                      sarah             Oily
# 2807               1            Jeff Index Test      Combination
# 910                2                      Audry           Normal
#
#                                                     SKU
# 2707  [8500, 8510, 6200, 7740, 7770, 6130, 3400, 276...
# 1863  [7830, 1350, 6200, 7740, 7860, 6130, 7690, 275...
# 437   [1150, 1350, 2010, 7740, 7870, 7800, 7690, 275...
# 2109  [1150, 1350, 8720, 7740, 7980, 6130, 3400, 275...
# 2687  [6002, 1350, 6200, 7740, 7870, 6130, 7690, 275...
# 604   [7830, 8510, 6200, 7740, 7860, 6130, 9180, 275...
# 379   [7830, 7670, 2040, 7740, 7860, 6130, 7690, 276...
# 596   [1150, 7670, 7820, 7740, 7870, 6130, 7690, 275...
# 1034  [7830, 1350, 2010, 7740, 7770, 6130, 7690, 276...
# 284   [7830, 7670, 6200, 7740, 7770, 6130, 7690, 276...
# 172   [1000, 1250, 8720, 2130, 7840, 6130, 7810, 280...
# 551   [1150, 1350, 8720, 7740, 7870, 7800, 8740, 275...
# 2726  [1150, 7670, 7820, 7740, 7870, 7800, 7690, 275...
# 115   [8500, 7670, 7660, 2130, 7870, 7970, 7810, 280...
# 2538  [8500, 8510, 7660, 7740, 7860, 1720, 8520, 275...
# 1850  [6002, 1350, 6200, 7740, 7870, 6130, 7690, 275...
# 2602  [6002, 1350, 2040, 7740, 7870, 6130, 8740, 275...
# Import shopify sales data
sales_data = pd.read_csv("shopify_orders_export_20180207.csv", 
                         low_memory=False, 
                         parse_dates=['Paid at', 'Fulfilled at', 'Created at'])

sales_data_clean = sales_data.drop(sales_data.columns.to_series()[-11:-1], axis=1)
sales_data_clean.dropna(subset=['Email'], axis=0, inplace=True)

sales_data_clean['discover_first_date'] = sales_data_clean['Email'].map(single_row_recommendations.set_index('email')['timestamp'])
sales_data_clean['used_discover_already'] = (sales_data_clean['Created at']> sales_data_clean['discover_first_date']).map({True: "Used Discover", False: "Not yet"})
sales_data_clean['discover_sales_lead_time'] = sales_data_clean['Created at'] - sales_data_clean['discover_first_date']

sales_data_clean =  sales_data_clean.merge(single_row_recommendations, left_on= 'Email', right_on='email',
                                           how='left')
pre_discover_sales = sales_data_clean[sales_data_clean['Created at']< "2017-09-09 03:25:00"]
post_discover_sales = sales_data_clean[sales_data_clean['Created at']>= "2017-09-09 03:25:00"]

# Now, serialize the transactions done by each customer

post_discover_sales['Buy Count'] = post_discover_sales.sort_values('Created at').dropna(subset= ['Paid at']).groupby(['Email'])['Paid at'].cumcount()+1
post_discover_sales['Buy Count'] = post_discover_sales['Buy Count'].ffill()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# pull a subset of data for testing
post_discover_sales[post_discover_sales['Email'] == 'Jennyann57@yahoo.com.sg']
# Out:
#               Name                    Email Financial Status  \
# 381   191569914513  Jennyann57@yahoo.com.sg             paid
# 382   191569914513  Jennyann57@yahoo.com.sg              NaN
# 1047  191569914151  Jennyann57@yahoo.com.sg             paid
# 1048  191569914150  Jennyann57@yahoo.com.sg             paid
# 1049  191569914150  Jennyann57@yahoo.com.sg              NaN
# 1050  191569914150  Jennyann57@yahoo.com.sg              NaN
# 3377  191569912957  Jennyann57@yahoo.com.sg             paid
# 3378  191569912957  Jennyann57@yahoo.com.sg              NaN
# 3379  191569912957  Jennyann57@yahoo.com.sg              NaN
# 3380  191569912957  Jennyann57@yahoo.com.sg              NaN
# 3381  191569912957  Jennyann57@yahoo.com.sg              NaN
# 3382  191569912957  Jennyann57@yahoo.com.sg              NaN
# 6565  191569911354  Jennyann57@yahoo.com.sg             paid
# 6566  191569911354  Jennyann57@yahoo.com.sg              NaN
# 6567  191569911354  Jennyann57@yahoo.com.sg              NaN
# 6568  191569911354  Jennyann57@yahoo.com.sg              NaN
# 6569  191569911354  Jennyann57@yahoo.com.sg              NaN
# 6570  191569911354  Jennyann57@yahoo.com.sg              NaN
# 9225   19156809966  Jennyann57@yahoo.com.sg             paid
# 9226   19156809966  Jennyann57@yahoo.com.sg              NaN
# 9227   19156809966  Jennyann57@yahoo.com.sg              NaN
#
#                  Paid at Fulfillment Status        Fulfilled at  \
# 381  2018-02-01 07:38:44          fulfilled 2018-02-02 11:40:43
# 382                  NaT                NaN                 NaT
# 1047 2018-01-22 06:44:25          fulfilled 2018-01-23 06:52:03
# 1048 2018-01-22 06:32:29          fulfilled 2018-01-23 11:41:12
# 1049                 NaT                NaN                 NaT
# 1050                 NaT                NaN                 NaT
# 3377 2017-12-12 13:46:28          fulfilled 2017-12-14 09:43:12
# 3378                 NaT                NaN                 NaT
# 3379                 NaT                NaN                 NaT
# 3380                 NaT                NaN                 NaT
# 3381                 NaT                NaN                 NaT
# 3382                 NaT                NaN                 NaT
# 6565 2017-10-26 07:53:53          fulfilled 2017-10-27 16:00:44
# 6566                 NaT                NaN                 NaT
# 6567                 NaT                NaN                 NaT
# 6568                 NaT                NaN                 NaT
# 6569                 NaT                NaN                 NaT
# 6570                 NaT                NaN                 NaT
# 9225 2017-09-13 11:22:13          fulfilled 2017-09-14 12:51:49
# 9226                 NaT                NaN                 NaT
# 9227                 NaT                NaN                 NaT
#
#      Accepts Marketing Currency  Subtotal  Shipping  Taxes  Total  \
# 381                yes      SGD     109.0       0.0    0.0  109.0
# 382                NaN      NaN       NaN       NaN    NaN    NaN
# 1047               yes      SGD      90.0       0.0    0.0   90.0
# 1048               yes      SGD     162.0       0.0    0.0  162.0
# 1049               NaN      NaN       NaN       NaN    NaN    NaN
# 1050               NaN      NaN       NaN       NaN    NaN    NaN
# 3377               yes      SGD     285.6       0.0    0.0  285.6
# 3378               NaN      NaN       NaN       NaN    NaN    NaN
# 3379               NaN      NaN       NaN       NaN    NaN    NaN
# 3380               NaN      NaN       NaN       NaN    NaN    NaN
# 3381               NaN      NaN       NaN       NaN    NaN    NaN
# 3382               NaN      NaN       NaN       NaN    NaN    NaN
# 6565               yes      SGD     270.0       0.0    0.0  270.0
# 6566               NaN      NaN       NaN       NaN    NaN    NaN
# 6567               NaN      NaN       NaN       NaN    NaN    NaN
# 6568               NaN      NaN       NaN       NaN    NaN    NaN
# 6569               NaN      NaN       NaN       NaN    NaN    NaN
# 6570               NaN      NaN       NaN       NaN    NaN    NaN
# 9225               yes      SGD     155.0       0.0    0.0  155.0
# 9226               NaN      NaN       NaN       NaN    NaN    NaN
# 9227               NaN      NaN       NaN       NaN    NaN    NaN
#
#           Discount Code  Discount Amount                 Shipping Method  \
# 381   25OFFc9d3577ca33e             25.0  Free Delivery (2 Working Days)
# 382                 NaN              NaN                             NaN
# 1047                NaN              0.0  Free Delivery (2 Working Days)
# 1048                NaN              0.0  Free Delivery (2 Working Days)
# 1049                NaN              NaN                             NaN
# 1050                NaN              NaN                             NaN
# 3377                NaN              0.0  Free Delivery (2 Working Days)
# 3378                NaN              NaN                             NaN
# 3379                NaN              NaN                             NaN
# 3380                NaN              NaN                             NaN
# 3381                NaN              NaN                             NaN
# 3382                NaN              NaN                             NaN
# 6565                NaN              0.0  Free Delivery (2 Working Days)
# 6566                NaN              NaN                             NaN
# 6567                NaN              NaN                             NaN
# 6568                NaN              NaN                             NaN
# 6569                NaN              NaN                             NaN
# 6570                NaN              NaN                             NaN
# 9225                NaN              0.0  Free Delivery (2 Working Days)
# 9226                NaN              NaN                             NaN
# 9227                NaN              NaN                             NaN
#
#               Created at  Lineitem quantity  \
# 381  2018-02-01 07:38:43                  1
# 382  2018-02-01 07:38:43                  2
# 1047 2018-01-22 06:44:24                  2
# 1048 2018-01-22 06:32:28                  2
# 1049 2018-01-22 06:32:28                  2
# 1050 2018-01-22 06:32:28                  1
# 3377 2017-12-12 13:46:28                  2
# 3378 2017-12-12 13:46:28                  1
# 3379 2017-12-12 13:46:28                  1
# 3380 2017-12-12 13:46:28                  1
# 3381 2017-12-12 13:46:28                  1
# 3382 2017-12-12 13:46:28                  1
# 6565 2017-10-26 07:53:53                  1
# 6566 2017-10-26 07:53:53                  1
# 6567 2017-10-26 07:53:53                  2
# 6568 2017-10-26 07:53:53                  1
# 6569 2017-10-26 07:53:53                  1
# 6570 2017-10-26 07:53:53                  1
# 9225 2017-09-13 11:22:13                  1
# 9226 2017-09-13 11:22:13                  1
# 9227 2017-09-13 11:22:13                  2
#
#                                           Lineitem name  Lineitem price  \
# 381     Skin Recovery Softening Cream Cleanser - 473 ml            50.0
# 382      Skin Recovery Replenishing Moisturizer - 60 ml            42.0
# 1047  Resist Skin Revealing Body Lotion 10% AHA (Gly...            45.0
# 1048            Clinical Ultra-Rich Moisturizer - 60 ml            48.0
# 1049  Resist Daily Smoothing Treatment 5% AHA (Glyco...            16.0
# 1050  Earth Sourced Perfectly Natural Cleansing Gel ...            34.0
# 3377                          PC4Men Face Wash - 177 ml            30.0
# 3378                   Rehydrating Moisture Mask - 88ml            27.6
# 3379  Resist Intensive Repair Cream with Retinol - 5...            48.0
# 3380                  Resist 1% Retinol Booster - 15 ml            76.0
# 3381        Resist Advanced Replenishing Toner - 118 ml            38.0
# 3382  Resist Optimal Results Hydrating Cleanser - 19...            36.0
# 6565      Skin Recovery Enriched Calming Toner - 190 ml            34.0
# 6566    Skin Recovery Softening Cream Cleanser - 237 ml            34.0
# 6567        Resist Smoothing Primer Serum SPF 30 - 30ml            43.0
# 6568                          PC4Men Face Wash - 177 ml            30.0
# 6569  Resist Intensive Repair Cream with Retinol - 5...            48.0
# 6570                    Refreshing Moisture Mist - 88ml            38.0
# 9225                       Resist Omega+ Complex - 30ml            59.0
# 9226  Resist Optimal Results Hydrating Cleanser - 19...            36.0
# 9227                          PC4Men Face Wash - 177 ml            30.0
#
#       Lineitem compare at price Lineitem sku  Lineitem requires shipping  \
# 381                         NaN         1051                        True
# 382                         NaN         1860                        True
# 1047                        NaN         5900                        True
# 1048                        NaN         5570                        True
# 1049                        NaN         7667                        True
# 1050                        0.0         8500                        True
# 3377                        NaN         8700                        True
# 3378                        NaN         2600                        True
# 3379                        NaN         7810                        True
# 3380                        NaN         7870                        True
# 3381                        NaN         7670                        True
# 3382                        NaN         7600                        True
# 6565                        NaN         1250                        True
# 6566                        NaN         1050                        True
# 6567                        NaN        91580                        True
# 6568                        NaN         8700                        True
# 6569                        NaN         7810                        True
# 6570                        NaN         2150                        True
# 9225                        NaN         2130                        True
# 9226                        NaN         7600                        True
# 9227                        NaN         8700                        True
#
#       Lineitem taxable Lineitem fulfillment status       Billing Name  \
# 381              False                   fulfilled  Jennifer Mitchell
# 382              False                   fulfilled                NaN
# 1047             False                   fulfilled  Jennifer Mitchell
# 1048             False                   fulfilled  Jennifer Mitchell
# 1049             False                   fulfilled                NaN
# 1050             False                   fulfilled                NaN
# 3377             False                   fulfilled  Jennifer Mitchell
# 3378              True                   fulfilled                NaN
# 3379             False                   fulfilled                NaN
# 3380             False                   fulfilled                NaN
# 3381             False                   fulfilled                NaN
# 3382             False                   fulfilled                NaN
# 6565             False                   fulfilled  Jennifer Mitchell
# 6566             False                   fulfilled                NaN
# 6567             False                   fulfilled                NaN
# 6568             False                   fulfilled                NaN
# 6569             False                   fulfilled                NaN
# 6570             False                   fulfilled                NaN
# 9225             False                   fulfilled  Jennifer Mitchell
# 9226             False                   fulfilled                NaN
# 9227             False                   fulfilled                NaN
#
#              Billing Street       Billing Address1 Billing Address2  \
# 381   93 Cashew Road #06-02  93 Cashew Road #06-02              NaN
# 382                     NaN                    NaN              NaN
# 1047  93 Cashew Road #06-02  93 Cashew Road #06-02              NaN
# 1048  93 Cashew Road #06-02  93 Cashew Road #06-02              NaN
# 1049                    NaN                    NaN              NaN
# 1050                    NaN                    NaN              NaN
# 3377  93 Cashew Road #06-02  93 Cashew Road #06-02              NaN
# 3378                    NaN                    NaN              NaN
# 3379                    NaN                    NaN              NaN
# 3380                    NaN                    NaN              NaN
# 3381                    NaN                    NaN              NaN
# 3382                    NaN                    NaN              NaN
# 6565  93 Cashew Road #06-02  93 Cashew Road #06-02              NaN
# 6566                    NaN                    NaN              NaN
# 6567                    NaN                    NaN              NaN
# 6568                    NaN                    NaN              NaN
# 6569                    NaN                    NaN              NaN
# 6570                    NaN                    NaN              NaN
# 9225  93 Cashew Road #06-02  93 Cashew Road #06-02              NaN
# 9226                    NaN                    NaN              NaN
# 9227                    NaN                    NaN              NaN
#
#      Billing Company Billing City Billing Zip Billing Province  \
# 381              NaN    Singapore     '679664              NaN
# 382              NaN          NaN         NaN              NaN
# 1047             NaN    Singapore     '679664              NaN
# 1048             NaN    Singapore     '679664              NaN
# 1049             NaN          NaN         NaN              NaN
# 1050             NaN          NaN         NaN              NaN
# 3377             NaN    Singapore     '679664              NaN
# 3378             NaN          NaN         NaN              NaN
# 3379             NaN          NaN         NaN              NaN
# 3380             NaN          NaN         NaN              NaN
# 3381             NaN          NaN         NaN              NaN
# 3382             NaN          NaN         NaN              NaN
# 6565             NaN    Singapore     '679664              NaN
# 6566             NaN          NaN         NaN              NaN
# 6567             NaN          NaN         NaN              NaN
# 6568             NaN          NaN         NaN              NaN
# 6569             NaN          NaN         NaN              NaN
# 6570             NaN          NaN         NaN              NaN
# 9225             NaN    Singapore     '679664              NaN
# 9226             NaN          NaN         NaN              NaN
# 9227             NaN          NaN         NaN              NaN
#
#      Billing Country Billing Phone      Shipping Name        Shipping Street  \
# 381               SG     9631 0007  Jennifer Mitchell  93 Cashew Road #06-02
# 382              NaN           NaN                NaN                    NaN
# 1047              SG     9631 0007  Jennifer Mitchell  93 Cashew Road #06-02
# 1048              SG     9631 0007  Jennifer Mitchell  93 Cashew Road #06-02
# 1049             NaN           NaN                NaN                    NaN
# 1050             NaN           NaN                NaN                    NaN
# 3377              SG     9631 0007  Jennifer Mitchell  93 Cashew Road #06-02
# 3378             NaN           NaN                NaN                    NaN
# 3379             NaN           NaN                NaN                    NaN
# 3380             NaN           NaN                NaN                    NaN
# 3381             NaN           NaN                NaN                    NaN
# 3382             NaN           NaN                NaN                    NaN
# 6565              SG     9631 0007  Jennifer Mitchell  93 Cashew Road #06-02
# 6566             NaN           NaN                NaN                    NaN
# 6567             NaN           NaN                NaN                    NaN
# 6568             NaN           NaN                NaN                    NaN
# 6569             NaN           NaN                NaN                    NaN
# 6570             NaN           NaN                NaN                    NaN
# 9225              SG     9631 0007  Jennifer Mitchell  93 Cashew Road #06-02
# 9226             NaN           NaN                NaN                    NaN
# 9227             NaN           NaN                NaN                    NaN
#
#           Shipping Address1 Shipping Address2 Shipping Company Shipping City  \
# 381   93 Cashew Road #06-02               NaN              NaN     Singapore
# 382                     NaN               NaN              NaN           NaN
# 1047  93 Cashew Road #06-02               NaN              NaN     Singapore
# 1048  93 Cashew Road #06-02               NaN              NaN     Singapore
# 1049                    NaN               NaN              NaN           NaN
# 1050                    NaN               NaN              NaN           NaN
# 3377  93 Cashew Road #06-02               NaN              NaN     Singapore
# 3378                    NaN               NaN              NaN           NaN
# 3379                    NaN               NaN              NaN           NaN
# 3380                    NaN               NaN              NaN           NaN
# 3381                    NaN               NaN              NaN           NaN
# 3382                    NaN               NaN              NaN           NaN
# 6565  93 Cashew Road #06-02               NaN              NaN     Singapore
# 6566                    NaN               NaN              NaN           NaN
# 6567                    NaN               NaN              NaN           NaN
# 6568                    NaN               NaN              NaN           NaN
# 6569                    NaN               NaN              NaN           NaN
# 6570                    NaN               NaN              NaN           NaN
# 9225  93 Cashew Road #06-02               NaN              NaN     Singapore
# 9226                    NaN               NaN              NaN           NaN
# 9227                    NaN               NaN              NaN           NaN
#
#      Shipping Zip Shipping Province Shipping Country Shipping Phone Notes  \
# 381       '679664               NaN               SG      9631 0007   NaN
# 382           NaN               NaN              NaN            NaN   NaN
# 1047      '679664               NaN               SG      9631 0007   NaN
# 1048      '679664               NaN               SG      9631 0007   NaN
# 1049          NaN               NaN              NaN            NaN   NaN
# 1050          NaN               NaN              NaN            NaN   NaN
# 3377      '679664               NaN               SG      9631 0007   NaN
# 3378          NaN               NaN              NaN            NaN   NaN
# 3379          NaN               NaN              NaN            NaN   NaN
# 3380          NaN               NaN              NaN            NaN   NaN
# 3381          NaN               NaN              NaN            NaN   NaN
# 3382          NaN               NaN              NaN            NaN   NaN
# 6565      '679664               NaN               SG      9631 0007   NaN
# 6566          NaN               NaN              NaN            NaN   NaN
# 6567          NaN               NaN              NaN            NaN   NaN
# 6568          NaN               NaN              NaN            NaN   NaN
# 6569          NaN               NaN              NaN            NaN   NaN
# 6570          NaN               NaN              NaN            NaN   NaN
# 9225      '679664               NaN               SG      9631 0007   NaN
# 9226          NaN               NaN              NaN            NaN   NaN
# 9227          NaN               NaN              NaN            NaN   NaN
#
#      Note Attributes Cancelled at Payment Method Payment Reference  \
# 381              NaN          NaN         Stripe   c541334896659.1
# 382              NaN          NaN            NaN               NaN
# 1047             NaN          NaN         Stripe   c507924578323.1
# 1048             NaN          NaN         Stripe   c507907440659.1
# 1049             NaN          NaN            NaN               NaN
# 1050             NaN          NaN            NaN               NaN
# 3377             NaN          NaN         Stripe   c233580822547.1
# 3378             NaN          NaN            NaN               NaN
# 3379             NaN          NaN            NaN               NaN
# 3380             NaN          NaN            NaN               NaN
# 3381             NaN          NaN            NaN               NaN
# 3382             NaN          NaN            NaN               NaN
# 6565             NaN          NaN         Stripe    c17872977939.1
# 6566             NaN          NaN            NaN               NaN
# 6567             NaN          NaN            NaN               NaN
# 6568             NaN          NaN            NaN               NaN
# 6569             NaN          NaN            NaN               NaN
# 6570             NaN          NaN            NaN               NaN
# 9225             NaN          NaN         Stripe    c16793168531.1
# 9226             NaN          NaN            NaN               NaN
# 9227             NaN          NaN            NaN               NaN
#
#       Refunded Amount          Vendor  Outstanding Balance Employee Location  \
# 381               0.0  Paula's Choice                  0.0      NaN      NaN
# 382               NaN  Paula's Choice                  NaN      NaN      NaN
# 1047              0.0  Paula's Choice                  0.0      NaN      NaN
# 1048              0.0  Paula's Choice                  0.0      NaN      NaN
# 1049              NaN  Paula's Choice                  NaN      NaN      NaN
# 1050              NaN  Paula's Choice                  NaN      NaN      NaN
# 3377              0.0  Paula's Choice                  0.0      NaN      NaN
# 3378              NaN  Paula's Choice                  NaN      NaN      NaN
# 3379              NaN  Paula's Choice                  NaN      NaN      NaN
# 3380              NaN  Paula's Choice                  NaN      NaN      NaN
# 3381              NaN  Paula's Choice                  NaN      NaN      NaN
# 3382              NaN  Paula's Choice                  NaN      NaN      NaN
# 6565              0.0  Paula's Choice                  0.0      NaN      NaN
# 6566              NaN  Paula's Choice                  NaN      NaN      NaN
# 6567              NaN  Paula's Choice                  NaN      NaN      NaN
# 6568              NaN  Paula's Choice                  NaN      NaN      NaN
# 6569              NaN  Paula's Choice                  NaN      NaN      NaN
# 6570              NaN  Paula's Choice                  NaN      NaN      NaN
# 9225              0.0  Paula's Choice                  0.0      NaN      NaN
# 9226              NaN  Paula's Choice                  NaN      NaN      NaN
# 9227              NaN  Paula's Choice                  NaN      NaN      NaN
#
#       Device ID            Id Tags Risk Level Source  Lineitem discount  \
# 381         NaN  1.725632e+11  NaN        Low    web                0.0
# 382         NaN           NaN  NaN        NaN    NaN                0.0
# 1047        NaN  1.609212e+11  NaN        Low    web                0.0
# 1048        NaN  1.609163e+11  NaN        Low    web                0.0
# 1049        NaN           NaN  NaN        NaN    NaN                0.0
# 1050        NaN           NaN  NaN        NaN    NaN                0.0
# 3377        NaN  9.798183e+10  NaN        Low    web                0.0
# 3378        NaN           NaN  NaN        NaN    NaN                0.0
# 3379        NaN           NaN  NaN        NaN    NaN                0.0
# 3380        NaN           NaN  NaN        NaN    NaN                0.0
# 3381        NaN           NaN  NaN        NaN    NaN                0.0
# 3382        NaN           NaN  NaN        NaN    NaN                0.0
# 6565        NaN  6.544589e+09  NaN        Low    web                0.0
# 6566        NaN           NaN  NaN        NaN    NaN                0.0
# 6567        NaN           NaN  NaN        NaN    NaN                0.0
# 6568        NaN           NaN  NaN        NaN    NaN                0.0
# 6569        NaN           NaN  NaN        NaN    NaN                0.0
# 6570        NaN           NaN  NaN        NaN    NaN                0.0
# 9225        NaN  6.109711e+09  NaN        Low    web                0.0
# 9226        NaN           NaN  NaN        NaN    NaN                0.0
# 9227        NaN           NaN  NaN        NaN    NaN                0.0
#
#       Phone discover_first_date used_discover_already  \
# 381     NaN 2018-01-22 05:55:41         Used Discover
# 382     NaN 2018-01-22 05:55:41         Used Discover
# 1047    NaN 2018-01-22 05:55:41         Used Discover
[8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        3.0
# 3378  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        3.0
# 3379  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        3.0
# 3380  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        3.0
# 3381  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        3.0
# 3382  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        3.0
# 6565  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        2.0
# 6566  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        2.0
# 6567  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        2.0
# 6568  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        2.0
# 6569  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        2.0
# 6570  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        2.0
# 9225  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        1.0
# 9226  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        1.0
# 9227  [8500, 7670, 7660, 2130, 7860, 7970, 5570, 280...        1.0

# %%
# post_discover_sales['Recommendation Buy Count'] = post_discover_sales.apply(lambda x: x['Lineitem sku'].isin(str(x['SKU'])))
# = post_discover_sales.apply(lambda x: True if x['Lineitem sku'] in list(map(str, x['SKU'])))

post_discover_sales['SKU'] = post_discover_sales['SKU'].fillna('N/A')
transaction_match_count = []

for serial in post_discover_sales['SKU'].index:
    buy_count_list = []
    buy_count = 0
    for sku_list in list(map(str, post_discover_sales['SKU'][serial])):
        if str(post_discover_sales['Lineitem sku'][serial]) in sku_list:
            buy_count_list.append(True)
        else: buy_count_list.append(False)
    transaction_match_count.append(sum(buy_count_list))
# print(transaction_match_count)

post_discover_sales['Bought Recommended'] = transaction_match_count # pd.Series(transaction_match_count).values
# post_discover_sales.to_excel('post_discover_sales.xlsx')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df = post_discover_sales[~(post_discover_sales['discover_first_date'].isnull()) & 
                    (post_discover_sales['used_discover_already'] == 'Used Discover') &
                        (post_discover_sales['Buy Count'] == 1)].groupby(['Email', 'discover_sales_lead_time', 'Created at', 'Buy Count'])['Bought Recommended'].sum()

# %%
# examine the percentage of recommendations bought in their first transaction after using discover

post_discover_first_purchase_numerator = pd.DataFrame(df).reset_index().drop_duplicates('Email', keep='first')
post_discover_first_purchase_numerator_count = len(post_discover_first_purchase_numerator[post_discover_first_purchase_numerator['Bought Recommended'] > 0])
post_discover_first_purchase_denom_count = len(post_discover_first_purchase_numerator)
print('Percentage of customers who bought from recommended list: {:.2f}%'.format(100*post_discover_first_purchase_numerator_count/post_discover_first_purchase_denom_count ))
print('Distribution of time to buy: \n{}'.format(post_discover_first_purchase_numerator['discover_sales_lead_time'].describe()))
# Out:
# Percentage of customers who bought from recommended list: 38.56%
# Distribution of time to buy:
# count                        459
# mean     10 days 09:52:34.335511
# std      21 days 14:08:58.974685
# min              0 days 00:00:03
# 25%              0 days 00:16:08
# 50%              0 days 10:20:09
# 75%       9 days 11:58:37.500000
# max            135 days 02:31:02
# Name: discover_sales_lead_time, dtype: object

# %% [markdown]
# ## Explore basic characteristics of Discover data

# %%
# examine number of people who retake the test
# Extract only email and timestamp from discover data
email_timestamp_unique = discover_data[['email', 'timestamp']].drop_duplicates(keep='last')
email_timestamp_unique

test_take_pivot_count = pd.pivot_table(email_timestamp_unique, index= 'email', aggfunc='count')
count_total_submissions = len(email_timestamp_unique)
print('total_submissions_count:', count_total_submissions)
retakers_count = test_take_pivot_count[test_take_pivot_count['timestamp'] >1 ].count()
print('retakers_count:', retakers_count)
print('Percentage of retakers: {0:.3f}%'.format(float(retakers_count/count_total_submissions)))
# Out:
# total_submissions_count: 3435
# retakers_count: timestamp    486
# dtype: int64
# Percentage of retakers: 0.141%

# %%
discover_data[['timestamp']].drop_duplicates(keep='last').count()
# Out:
# timestamp    3432
# dtype: int64

# %%
# Male Female Breakdown
email_gender_unique = discover_data[['email', 'request.gender']].drop_duplicates(keep='last')
male_email_count = len(email_gender_unique[email_gender_unique['request.gender'] == 1])
print('male_email_count:', male_email_count)
female_email_count = len(email_gender_unique[email_gender_unique['request.gender'] == 2])
print('female_email_count:', female_email_count)
female_percentage = female_email_count/(male_email_count + female_email_count)
print('male_percentage: {0:.2f}%'.format(1-female_percentage))
print('female_percentage: {0:.2f}%'.format(female_percentage))
# Out:
# male_email_count: 297
# female_email_count: 2163
# male_percentage: 0.12%
# female_percentage: 0.88%

# %%
len(email_gender_unique[email_gender_unique['request.gender'] == 0])
# Out:
# 134

# %%
# Age range distribution
email_age_unique = discover_data[['email', 'request.ageRange']].drop_duplicates(keep='last')
age_range_breakdown = email_age_unique.groupby('request.ageRange').count() #apply(lambda x: 100 * x / x.sum())
age_range_breakdown['Percentage'] =age_range_breakdown.apply(lambda x: 100 * x / x.sum())
age_range_breakdown # age_range_breakdown['Percentage'] = age_range_breakdown['email'].map(lambda x: 100 * x / x.sum())
# Out:
#                   email  Percentage
# request.ageRange
# 20.0                142    6.454545
# 30.0               1113   50.590909
# 40.0                768   34.909091
# 60.0                128    5.818182
# 70.0                 49    2.227273

# %%
age_range_breakdown.sum()
# Out:
# email         2200.0
# Percentage     100.0
# dtype: float64

# %%
# Calculates how many people DID NOT indicate ageRange

len(email_age_unique[pd.isnull(email_age_unique['request.ageRange']) == True])
# Out:
# 373

# %% [markdown]
# # Part 2 - Match Discover takers with Sales Data
# ## Objectives:
# ### 1. Obtain a list SKUs bought right after they have taken Discover
# ### 2. Match the list with the skin profile (and any other relevant "features")

# %%
# Import shopify sales data
sales_data = pd.read_csv("shopify_orders_export_20180207.csv", 
                         low_memory=False, 
                         parse_dates=['Paid at', 'Fulfilled at', 'Created at'])

sales_data_clean = sales_data.drop(sales_data.columns.to_series()[-11:-1], axis=1)

# remove in-store purchases by dropping NA rows in Email column
sales_data_clean.dropna(subset=['Email'], axis=0, inplace=True)

# add columns referencing each customer's FIRST use of discover
sales_data_clean['discover_first_date'] = sales_data_clean['Email'].map(discover_first.set_index('email')['timestamp2'])
sales_data_clean['used_discover_already'] = (sales_data_clean['Created at']> \
                                             sales_data_clean['discover_first_date']).\
                                                map({True: "Used Discover", False: "Not yet"})
sales_data_clean['discover_sales_lead_time'] = sales_data_clean['Created at'] - sales_data_clean['discover_first_date']

# create sales dataset filtering customers who had used discover
# regardless of whether they are existing or completely new customers
post_discover_sales = sales_data_clean[sales_data_clean['used_discover_already'] == "Used Discover"]

# create sales dataset filtering customers who have never used discover and
# and also those customers' purchase histories right before they use discover
pre_discover_sales = sales_data_clean[~(sales_data_clean['used_discover_already'] == "Used Discover")]

# %%
df1 = pd.DataFrame({"Name":["Alice", "Bob", "Mallory", "Mallory", "Bob" , "Mallory"],
                    "City":["Seattle","Seattle","Portland","Seattle","Seattle","Portland"],
                   'Value': [0,1,2,3, 4,5]})
df1.pivot_table(index = 'City', columns = 'Name', aggfunc='sum')
# Out:
#          Value
# Name     Alice  Bob Mallory
# City
# Portland   NaN  NaN     7.0
# Seattle    0.0  5.0     3.0
